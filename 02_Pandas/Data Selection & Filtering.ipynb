# %% [markdown]
# # Data Selection & Filtering
#
# Selecting the right rows and columns is the first step in analyzing any dataset. Pandas gives you several powerful ways to do this.

# %%
import pandas as pd

df = pd.read_csv("data.json.csv")
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 1                    565   6.0
# 2                   2024   8.4
# 3                    431   5.6
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 9                    266   5.9
# 10                   201   6.1
# 11                   342   8.2

# %% [markdown]
# ### Selecting Rows & Columns
#
# Selecting Columns

# %%
df['Actor']  #Single Column (as series)
# Out:
# 0         Shah Rukh Khan
# 1            Salman Khan
# 2             Aamir Khan
# 3          Ranbir Kapoor
# 4          Ranveer Singh
# 5     Ayushmann Khurrana
# 6          Rajkummar Rao
# 7         Hrithik Roshan
# 8           Akshay Kumar
# 9          Kartik Aaryan
# 10          Varun Dhawan
# 11         Vicky Kaushal
# Name: Actor, dtype: object

# %%
df[['Actor','IMDb']] # Multiple column(as DataFrame)
# Out:
#                  Actor  IMDb
# 0       Shah Rukh Khan   7.2
# 1          Salman Khan   6.0
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %% [markdown]
# ### Selecting Rows by Index
# Use **.loc[]** (label-based) and **.iloc[]** (position-based):

# %%
df.loc[1] #by lable
# Out:
# Actor                       Salman Khan
# Film                    Tiger Zinda Hai
# Year                               2017
# Genre                            Action
# BoxOffice(INR Crore)                565
# IMDb                                6.0
# Name: 1, dtype: object

# %%
df.iloc[1] #bt position(integer : starting with 0 )
# Out:
# Actor                       Salman Khan
# Film                    Tiger Zinda Hai
# Year                               2017
# Genre                            Action
# BoxOffice(INR Crore)                565
# IMDb                                6.0
# Name: 1, dtype: object

# %% [markdown]
# ### Select Specific Rows and Columns

# %%
df.loc[8,"IMDb"] # value at row 8.column "Name"
# Out:
# np.float64(7.0)

# %%
df.iloc[8,5] # value ate row 8 , column at index 5
# Out:
# np.float64(7.0)

# %% [markdown]
# You can also slice:

# %%
df.loc[0:2,["Actor","IMDb"]] # last index inclusive   # Rows 0 to 2, selected columns
df.iloc[0:2, 0:2]
# Out:
#             Actor             Film
# 0  Shah Rukh Khan          Pathaan
# 1     Salman Khan  Tiger Zinda Hai

# %%
df.iloc[0:2,0:2] # last index exclusive # Rows and cols by index position
# Out:
#             Actor             Film
# 0  Shah Rukh Khan          Pathaan
# 1     Salman Khan  Tiger Zinda Hai

# %% [markdown]
# ### Fast Access: .at and .iat
# These are optimized for single element access:

# %%
df.at[0,"Actor"]  # Fast label-based access
# Out:
# 'Shah Rukh Khan'

# %%
df.iat[0,0]   # Fast position-based access
# Out:
# 'Shah Rukh Khan'

# %% [markdown]
# ### Filtering with Conditions
# Simple Condition

# %%
df[df["IMDb"]>6]
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 10                   201   6.1
# 11                   342   8.2

# %% [markdown]
# Multiple Conditions (AND / OR)

# %%
df[(df["IMDb"]>6) & (df["Year"]>2018)]
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 7   Hrithik Roshan                       War  2019  Action
# 8     Akshay Kumar                Good Newwz  2019  Comedy
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2

# %%
df[(df["IMDb"]>6) | (df["Year"]>2018)]
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 3                    431   5.6
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 9                    266   5.9
# 10                   201   6.1
# 11                   342   8.2

# %% [markdown]
# Use parentheses around each condition!

# %% [markdown]
# ### Querying with .query()
# The .query() method in pandas lets you filter DataFrame rows using a string expression — it's a more readable and often more concise alternative to using boolean indexing.
#
# This is a cleaner, SQL-like way to filter:

# %%
df.query("Year > 2018 and IMDb > 6")
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 7   Hrithik Roshan                       War  2019  Action
# 8     Akshay Kumar                Good Newwz  2019  Comedy
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2

# %% [markdown]
# Dynamic column names:

# %%
col = "IMDb"
df.query(f"{col} > 6")
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 10                   201   6.1
# 11                   342   8.2

# %% [markdown]
# Here are the main rules and tips for using .query() in pandas:

# %% [markdown]
# ## 1. Column names become variables
# You can reference column names directly in the query string:

# %%
df.query("Year > 2018 and IMDb > 6")
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 7   Hrithik Roshan                       War  2019  Action
# 8     Akshay Kumar                Good Newwz  2019  Comedy
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2

# %% [markdown]
# ## 2. String values must be in quotes
# Use single or double quotes around strings in the expression:

# %%
df.query("Actor == 'Shah Rukh Khan'")
# Out:
#             Actor     Film  Year   Genre  BoxOffice(INR Crore)  IMDb
# 0  Shah Rukh Khan  Pathaan  2023  Action                  1050   7.2

# %% [markdown]
# If you have quotes inside quotes. Mix them:

# %%
df.query('Genre == "Action"')
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 1      Salman Khan           Tiger Zinda Hai  2017  Action
# 7   Hrithik Roshan                       War  2019  Action
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 1                    565   6.0
# 7                    475   6.5
# 11                   342   8.2

# %% [markdown]
# ## 3. Use backticks for column names with spaces or special characters
#
# If a column name has spaces, use backticks (`):

# %% [markdown]
# df.query("`first name` == 'Alice'")

# %% [markdown]
# ## 4. You can use @ to reference Python variables
# To pass external variables into .query():

# %%
year_limit = 2019
df.query("Year < @year_limit")
# Out:
#                  Actor                   Film  Year            Genre  \
# 1          Salman Khan        Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                 Dangal  2016        Biography
# 4        Ranveer Singh              Padmaavat  2018       Historical
# 5   Ayushmann Khurrana              Andhadhun  2018         Thriller
# 6        Rajkummar Rao                  Stree  2018    Horror Comedy
# 10        Varun Dhawan  Badrinath Ki Dulhania  2017  Romantic Comedy
#
#     BoxOffice(INR Crore)  IMDb
# 1                    565   6.0
# 2                   2024   8.4
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 10                   201   6.1

# %% [markdown]
# ## 5. Logical operators
# Use these:
#
# and, or, not — instead of &, |, ~
#
# these are also use:
# ==, !=, <, >, <=, >=

# %% [markdown]
# ## 6. Chained comparisons
# Just like Python:

# %%
df.query("6 < IMDb < 8")
# Out:
#              Actor                   Film  Year            Genre  \
# 0   Shah Rukh Khan                Pathaan  2023           Action
# 4    Ranveer Singh              Padmaavat  2018       Historical
# 6    Rajkummar Rao                  Stree  2018    Horror Comedy
# 7   Hrithik Roshan                    War  2019           Action
# 8     Akshay Kumar             Good Newwz  2019           Comedy
# 10    Varun Dhawan  Badrinath Ki Dulhania  2017  Romantic Comedy
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 4                    585   7.0
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 10                   201   6.1

# %% [markdown]
# ## 7. Avoid using reserved keywords as column names
# If you have a column named class, lambda, etc., you’ll need to use backticks:

# %% [markdown]
# df.query("`class` == 'Physics'")

# %% [markdown]
# ## 8. Case-sensitive
# Column names and string values are case-sensitive:

# %%
df.query("Film == 'Pathaan' ") # we can not write small f in Film and small P in value
# Out:
#             Actor     Film  Year   Genre  BoxOffice(INR Crore)  IMDb
# 0  Shah Rukh Khan  Pathaan  2023  Action                  1050   7.2

# %% [markdown]
# ## 9. .query() returns a copy, not a view
# The result is a new DataFrame. Changes won't affect the original unless reassigned:

# %%
filter = df.query("IMDb > 6")
filter
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 10                   201   6.1
# 11                   342   8.2

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 1                    565   6.0
# 2                   2024   8.4
# 3                    431   5.6
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 9                    266   5.9
# 10                   201   6.1
# 11                   342   8.2

# %% [markdown]
# ## Summary
# Use df[col], .loc[], .iloc[], .at[], .iat[] to access data
#
# Filter with logical conditions or .query() for readable code
#
# Mastering selection makes the rest of pandas feel easy
